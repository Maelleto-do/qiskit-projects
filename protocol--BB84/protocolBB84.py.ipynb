# %%
pip install --upgrade qiskit==0.19.1
# Out:
# ...
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\maell\Install\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\maell\\AppData\\Local\\Temp\\pip-install-sworzbzl\\qiskit-aer_525470ac101645baa8f1ec2000ec1f9a\\setup.py'"'"'; __file__='"'"'C:\\Users\\maell\\AppData\\Local\\Temp\\pip-install-sworzbzl\\qiskit-aer_525470ac101645baa8f1ec2000ec1f9a\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\maell\AppData\Local\Temp\pip-wheel-grln5x3c'
#        cwd: C:\Users\maell\AppData\Local\Temp\pip-install-sworzbzl\qiskit-aer_525470ac101645baa8f1ec2000ec1f9a\
#   Complete output (293 lines):
#
#
# ...
